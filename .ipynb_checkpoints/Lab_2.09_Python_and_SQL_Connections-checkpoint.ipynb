# %%
import pandas as pd
import numpy as np

# for getting data from a SQL database
import pymysql    

# for establishing the connection and authentication
from sqlalchemy import create_engine  

# To get the password without showing the input
from getpass import getpass

# %%
password = getpass()
# Out:
# ········

# %%
connection_string = 'mysql+pymysql://root:'+password+'@localhost/sakila'
# print(connection_string)
engine = create_engine(connection_string)

# %%
type(engine)
# Out:
# sqlalchemy.engine.base.Engine

# %% [markdown]
# # How many distinct (different) actors' last names are there?

# %%
last_name_query = """
Select last_name, count(last_name) as occurrences
From actor
group by last_name
having count(last_name) = 1;
"""
last_name_query
# Out:
# '\nSelect last_name, count(last_name) as occurrences\nFrom actor\ngroup by last_name\nhaving count(last_name) = 1;\n'

# %%
last_name_df = pd.read_sql_query(last_name_query, engine)
last_name_df
# Out:
#       last_name  occurrences
# 0       ASTAIRE            1
# 1        BACALL            1
# 2          BALE            1
# 3          BALL            1
# 4     BARRYMORE            1
# ..          ...          ...
# 61       WALKEN            1
# 62        WAYNE            1
# 63       WILSON            1
# 64  WITHERSPOON            1
# 65         WRAY            1
#
# [66 rows x 2 columns]

# %% [markdown]
# # Add an additional column day_type with values 'weekend' and 'workday' depending on the rental day of the week.

# %%
day_type_query = """
Select *,
case when weekday(rental_date) = 5 or weekday(rental_date) = 6 then "weekend"
else "workday"
end as day_type
From rental
order by rental_date;
"""
day_type_query
# Out:
# '\nSelect *,\ncase when weekday(rental_date) = 5 or weekday(rental_date) = 6 then "weekend"\nelse "workday"\nend as day_type\nFrom rental\norder by rental_date;\n'

# %%
day_type_df = pd.read_sql_query(day_type_query, engine)
day_type_df[478:495]
# Out:
#      rental_id         rental_date  inventory_id  customer_id  \
# 478        480 2005-05-27 22:47:39          2108          220
# 479        481 2005-05-27 22:49:27            72          445
# 480        482 2005-05-27 22:53:02          4178          546
# 481        483 2005-05-27 23:00:25          1510           32
# 482        484 2005-05-27 23:26:45          3115          491
# 483        485 2005-05-27 23:40:52          2392          105
# 484        486 2005-05-27 23:51:12          1822          398
# 485        487 2005-05-28 00:00:30          3774          569
# 486        488 2005-05-28 00:07:50           393          168
# 487        489 2005-05-28 00:09:12          1940          476
# 488        490 2005-05-28 00:09:56          3524           95
# 489        491 2005-05-28 00:13:35          1326          196
# 490        492 2005-05-28 00:24:58          1999          228
# 491        493 2005-05-28 00:34:11           184          501
# 492        494 2005-05-28 00:39:31          1850           64
# 493        495 2005-05-28 00:40:48          1007          526
# 494        496 2005-05-28 00:43:41          1785           56
#
#             return_date  staff_id         last_update day_type
# 478 2005-06-04 21:17:39         2 2006-02-15 21:30:53  workday
# 479 2005-05-30 17:46:27         2 2006-02-15 21:30:53  workday
# 480 2005-06-01 22:53:02         2 2006-02-15 21:30:53  workday
# 481 2005-05-28 21:30:25         1 2006-02-15 21:30:53  workday
# 482 2005-05-29 21:16:45         2 2006-02-15 21:30:53  workday
# 483 2005-05-28 22:40:52         2 2006-02-15 21:30:53  workday
# 484 2005-05-28 20:26:12         1 2006-02-15 21:30:53  workday
# 485 2005-05-28 19:18:30         2 2006-02-15 21:30:53  weekend
# 486 2005-06-03 22:30:50         2 2006-02-15 21:30:53  weekend
# 487 2005-05-31 04:44:12         2 2006-02-15 21:30:53  weekend
# 488 2005-05-30 22:32:56         2 2006-02-15 21:30:53  weekend
# 489 2005-05-29 00:11:35         2 2006-02-15 21:30:53  weekend
# 490 2005-05-28 22:34:58         1 2006-02-15 21:30:53  weekend
# 491 2005-05-30 18:40:11         1 2006-02-15 21:30:53  weekend
# 492 2005-06-02 19:35:31         1 2006-02-15 21:30:53  weekend
# 493 2005-05-29 06:07:48         1 2006-02-15 21:30:53  weekend
# 494 2005-06-04 03:56:41         1 2006-02-15 21:30:53  weekend

# %% [markdown]
# # Get all films with ARMAGEDDON in the title.

# %%
title_query = """
Select *
from film
where title like '%%ARMAGEDD%%';
"""

title_query
# Out:
# "\nSelect *\nfrom film\nwhere title like '%%ARMAGEDD%%';\n"

# %%
title_df = pd.read_sql_query(title_query, engine)
title_df
# Out:
#    film_id                  title  \
# 0       39        ARMAGEDDON LOST
# 1      507    LADYBUGS ARMAGEDDON
# 2      571       METAL ARMAGEDDON
# 3      598    MOSQUITO ARMAGEDDON
# 4      838  STAGECOACH ARMAGEDDON
# 5      844      STEERS ARMAGEDDON
#
#                                          description  release_year  \
# 0  A Fast-Paced Tale of a Boat And a Teacher who ...          2006
# 1  A Fateful Reflection of a Dog And a Mad Scient...          2006
# 2  A Thrilling Display of a Lumberjack And a Croc...          2006
# 3  A Thoughtful Character Study of a Waitress And...          2006
# 4  A Touching Display of a Pioneer And a Butler w...          2006
# 5  A Stunning Character Study of a Car And a Girl...          2006
#
#    language_id original_language_id  rental_duration  rental_rate  length  \
# 0            1                 None                5         0.99      99
# 1            1                 None                4         0.99     113
# 2            1                 None                6         2.99     161
# 3            1                 None                6         0.99      57
# 4            1                 None                5         4.99     112
# 5            1                 None                6         4.99     140
#
#    replacement_cost rating                                   special_features  \
# 0             10.99      G                                           Trailers
# 1             13.99  NC-17                                     Deleted Scenes
# 2             26.99  PG-13               Trailers,Commentaries,Deleted Scenes
# 3             22.99      G                                           Trailers
# 4             25.99      R                            Trailers,Deleted Scenes
# 5             16.99     PG  Trailers,Commentaries,Deleted Scenes,Behind th...
#
#           last_update
# 0 2006-02-15 05:03:42
# 1 2006-02-15 05:03:42
# 2 2006-02-15 05:03:42
# 3 2006-02-15 05:03:42
# 4 2006-02-15 05:03:42
# 5 2006-02-15 05:03:42

# %% [markdown]
# # Get 10 the longest films.

# %%
longest_film_query = """
Select title, length
From film
order by length desc
limit 10;
"""

longest_film_query
# Out:
# '\nSelect title, length\nFrom film\norder by length desc\nlimit 10;\n'

# %%
longest_film_df = pd.read_sql_query(longest_film_query, engine)
longest_film_df
# Out:
#                 title  length
# 0      DARN FORRESTER     185
# 1        POND SEATTLE     185
# 2       CHICAGO NORTH     185
# 3       MUSCLE BRIGHT     185
# 4        WORST BANGER     185
# 5         GANGS PRIDE     185
# 6  SOLDIERS EVOLUTION     185
# 7           HOME PITY     185
# 8   SWEET BROTHERHOOD     185
# 9      CONTROL ANTHEM     185

# %% [markdown]
# # How many films include Behind the Scenes content?

# %%
bts_query = """
Select count(*) as 'BTS films'
From film
where special_features like "%%Behind the Scenes%%"
"""

bts_query
# Out:
# '\nSelect count(*) as \'BTS films\'\nFrom film\nwhere special_features like "%%Behind the Scenes%%"\n'

# %%
bts_df = pd.read_sql_query(bts_query, engine)
bts_df
# Out:
#    BTS films
# 0        538

# %% [markdown]
# # Which kind of movies (rating) have a mean duration of more than two hours?

# %%
more_than_2_hours_query = """
Select rating, round(avg(length), 2) as Average_duration
from film
group by rating
having Average_duration > 120;
"""

more_than_2_hours_query
# Out:
# '\nSelect rating, round(avg(length), 2) as Average_duration\nfrom film\ngroup by rating\nhaving Average_duration > 120;\n'

# %%
more_than_2_hours_df = pd.read_sql_query(more_than_2_hours_query, engine)
more_than_2_hours_df
# Out:
#   rating  Average_duration
# 0  PG-13            120.44

# %% [markdown]
# # Rank films by length (filter out the rows that have nulls or 0s in length column). In your output, only select the columns title, length, and the rank.

# %%
filter_query = """
Select title, length
From film
where length != Null or length > 0
order by 2;
"""

filter_query
# Out:
# '\nSelect title, length\nFrom film\nwhere length != Null or length > 0\norder by 2;\n'

# %%
filter_df = pd.read_sql_query(filter_query, engine)
filter_df
# Out:
#                    title  length
# 0           ALIEN CENTER      46
# 1              IRON MOON      46
# 2          KWAI HOMEWARD      46
# 3       LABYRINTH LEAGUE      46
# 4    RIDGEMONT SUBMARINE      46
# ..                   ...     ...
# 995        MUSCLE BRIGHT     185
# 996         POND SEATTLE     185
# 997   SOLDIERS EVOLUTION     185
# 998    SWEET BROTHERHOOD     185
# 999         WORST BANGER     185
#
# [1000 rows x 2 columns]
